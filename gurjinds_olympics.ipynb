# %% [markdown]
# <a href="https://colab.research.google.com/github/aaron-umich/SecurityAppPrototype/blob/master/gurjinds_olympics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
legos = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/olympic_medals.csv')
legos.head()
# Out:
#    Gender       Event  ... Nationality    Result
# 0       M  10000M Men  ...         GBR  25:05.17
# 1       M  10000M Men  ...         KEN  27:05.64
# 2       M  10000M Men  ...         ETH  27:06.26
# 3       M  10000M Men  ...         ETH  27:01.17
# 4       M  10000M Men  ...         ETH  27:02.77
# ..    ...         ...  ...         ...       ...
# 95      M    100M Men  ...         GBR      10.4
# 96      M    100M Men  ...         USA      10.3
# 97      M    100M Men  ...         USA      10.4
# 98      M    100M Men  ...         NED      10.5
# 99      M    100M Men  ...         CAN      10.8
#
# [100 rows x 8 columns]

# %%
len(legos.columns)
# Out:
# 8

# %%
len(legos.index)
# Out:
# 2394

# %%
legos.dtypes
# Out:
# Gender         object
# Event          object
# Location       object
# Year            int64
# Medal          object
# Name           object
# Nationality    object
# Result         object
# dtype: object

# %%
for index, row in legos.iterrows():
  print(index, row['Location'])
# Out:
# 0 Rio
# 1 Rio
# 2 Rio
# 3 Beijing
# 4 Beijing
# 5 Beijing
# 6 Sydney
# 7 Sydney
# 8 Sydney
# 9 Barcelona
# 10 Barcelona
# 11 Barcelona
# 12 Los Angeles
# 13 Los Angeles
# 14 Los Angeles
# 15 Montreal
# 16 Montreal
# 17 Montreal
# 18 Mexico
# 19 Mexico
# 20 Mexico
# 21 Rome
# 22 Rome
# 23 Rome
# 24 Helsinki
# 25 Helsinki
# 26 Helsinki
# 27 Berlin
# 28 Berlin
# 29 Berlin
# 30 Amsterdam
# 31 Amsterdam
# 32 Amsterdam
# 33 Antwerp
# 34 Antwerp
# 35 Antwerp
# 36 London
# 37 London
# 38 London
# 39 Athens
# 40 Athens
# 41 Athens
# 42 Atlanta
# 43 Atlanta
# 44 Atlanta
# 45 Moscow
# 46 Moscow
# 47 Moscow
# 48 Munich
# 49 Munich
# 50 Munich
# 51 Tokyo
# 52 Tokyo
# 53 Tokyo
# 54 Melbourne / Stockholm
# 55 Melbourne / Stockholm
# 56 Melbourne / Stockholm
# 57 London
# 58 London
# 59 London
# 60 Los Angeles
# 61 Los Angeles
# 62 Los Angeles
# 63 Paris
# 64 Paris
# 65 Paris
# 66 Stockholm
# 67 Stockholm
# 68 Stockholm
# 69 Rio
# 70 Rio
# 71 Rio
# 72 Beijing
# 73 Beijing
# 74 Beijing
# 75 Sydney
# ...

# %%
legos.loc[legos['Nationality']=='USA'].value_counts().describe()
# Out:
# count    577.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# dtype: float64

# %%
legos.loc[legos['Nationality']=='USA'].groupby('Nationality').count()
# Out:
#              Gender  Event  Location  Year  Medal  Name  Result
# Nationality
# USA             638    638       638   638    638   577     638
